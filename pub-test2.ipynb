# %%
#@markdown # PART 3 - START KILLING CORVIKNIGHTS
#@markdown ez pz japaneasy

from IPython.utils import capture
import os
import time
import sys
import re

Use_cf_Tunnel=True
password = "duckyduck"

if Use_cf_Tunnel:
  with capture.capture_output() as cap:
    # !pkill cl
    time.sleep(4)
    os.system("cl tunnel --url http://localhost:7860 > /kaggle/working/srv.txt 2>&1 &")
    time.sleep(4)
    with open('/kaggle/working/srv.txt', "r") as file: text = file.read()
    srv= re.findall(r"https?://(?:\S+?\.)?trycloudflare\.com\S*", text)[0]
import time

# List of ANSI color codes for rainbow colors with bold and bright background
rainbow_colors = [
    "\033[1;97;41m",  # Bold White text on Red background
    "\033[1;97;43m",  # Bold White text on Yellow background
    "\033[1;97;42m",  # Bold White text on Green background
    "\033[1;97;46m",  # Bold White text on Cyan background
    "\033[1;97;44m",  # Bold White text on Blue background
    "\033[1;97;45m",  # Bold White text on Magenta background
]

# Function to print "your ui link is " followed by srv in enhanced rainbow colors
def print_rainbow_text_with_srv(text, srv,):
    for color in rainbow_colors:
        colored_text = f"{color}{text}\033[0m{srv}{color}"
        print(colored_text + "\033[0m")
        time.sleep(0.5)  # Pause for half a second between prints

# Example srv variable (replace with your actual srv variable)


# Text to print
text_to_print = "your ui link is "

# Call the function
print_rainbow_text_with_srv(text_to_print, srv,)


# %cd /kaggle/working/duckarus
extradirs='--ckpt-dir /kaggle/temp/models'
#ckptdir='--ckpt-dir /kaggle/working/models'
ckptdir=''
